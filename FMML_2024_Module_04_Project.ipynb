# %% [markdown]
# <a href="https://colab.research.google.com/github/harshik25/FMML/blob/main/FMML_2024_Module_04_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Foundations of Modern Machine Learning, IIIT Hyderabad
#
# Project: Perceptron and Gradient Descent
#
# Note: Please write the code for the following tasks in separate code cells.

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# ### Example 1 - A simple cost function
#
# #### $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the range of x-values and the function
x_1 = np.linspace(-3, 3, 100)  # 100 points between -3 and 3
f_x = x_1**2  # f(x) = x^2

# Set up the plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f_x, label="f(x) = x^2")  # Adding a label for the function
plt.legend()  # Show the legend
plt.show()

# %% [markdown]
# ### Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ### Gradient Descent

# %%
# Define the function and its derivative
def f(x):
    return x**2  # Example: a simple quadratic function

def df(x):
    return 2*x  # Derivative of f(x)

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(new_x)  # [REQUIRED]
    new_x = previous_x - step_multiplier * gradient  # [REQUIRED]

    step_size = abs(new_x - previous_x)

    x_list.append(new_x)
    slope_list.append(df(new_x))  # [REQUIRED]

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: 3.425394462494306e-05
# Slope or df(x) value at this point is: 6.850788924988612e-05
# f(x) value or cost at this point is: 1.1733327223686654e-09

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# ### Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# #### $$g(x) = x^4 - 4x^2 + 5$$

# %%
import numpy as np

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**3 - 3*x + 2  # [REQUIRED] Example function

def dg(x):
    return 3*x**2 - 3  # [REQUIRED] Derivative of g(x)

# %%
import matplotlib.pyplot as plt

# Plot the function and its derivative
plt.figure(figsize=(10, 6))
plt.plot(x_2, g(x_2), label='g(x)', color='blue')
plt.plot(x_2, dg(x_2), label="g'(x)", color='red', linestyle='--')
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Function g(x) and its Derivative g\'(x)')
plt.legend()
plt.grid()
plt.show()

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier
import matplotlib.pyplot as plt
import numpy as np

# Define the function and its derivative
def g(x):
    return x**3 - 3*x + 2  # Example function

def dg(x):
    return 3*x**2 - 3  # Derivative of g(x)

# Make some data
x_2 = np.linspace(-2, 2, 1000)

# Create side-by-side plots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot g(x) on the first subplot
axes[0].plot(x_2, g(x_2), label='g(x)', color='blue')
axes[0].axhline(0, color='black', linewidth=0.8, linestyle='--')
axes[0].set_title('Function g(x)', fontsize=14)
axes[0].set_xlabel('x', fontsize=12)
axes[0].set_ylabel('g(x)', fontsize=12)
axes[0].grid()
axes[0].legend()

# Plot g'(x) on the second subplot
axes[1].plot(x_2, dg(x_2), label="g'(x)", color='red', linestyle='--')
axes[1].axhline(0, color='black', linewidth=0.8, linestyle='--')
axes[1].set_title('Derivative g\'(x)', fontsize=14)
axes[1].set_xlabel('x', fontsize=12)
axes[1].set_ylabel("g'(x)", fontsize=12)
axes[1].grid()
axes[1].legend()

# Show the plots
plt.tight_layout()
plt.show()

# %%
# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# Define the function and its derivative
def f(x):
    return x**2  # Example: f(x) = x^2

def df(x):
    return 2*x  # Derivative: f'(x) = 2x

# Perform gradient descent
min_x, x_list, slope_list = gradient_descent(df, initial_guess=3, multiplier=0.1, precision=0.0001)

# Results
print(f"Local minimum occurs at x = {min_x}")
print(f"f(x) at this point = {f(min_x)}")

# Visualization
import matplotlib.pyplot as plt
import numpy as np

# Data for the function
x = np.linspace(-3, 3, 100)
y = f(x)

# Plot the function
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='f(x) = x^2', color='blue')

# Plot the descent path
plt.scatter(x_list, [f(i) for i in x_list], color='red', label='Descent Path')
plt.title('Gradient Descent Optimization')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()
# Out:
# Local minimum occurs at x = 0.00039876839873547495
# f(x) at this point = 1.5901623583005473e-07

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0.9930744661434007
# Number of steps: 37

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0.9984585459099241
# Number of steps: 136

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0.993339412301493
# Number of steps: 48

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# ### Example 3 - Divergence and Overflow
#
# #### $$h(x) = x^5 - 2x^4 + 2$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and its derivative
def g(x):
    return x**3 - 3*x + 2  # Example function

def dg(x):
    return 3*x**2 - 3  # Derivative of g(x)

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %% [markdown]
# #### Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  36

# %%
# Define parameters
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                             multiplier=0.0005, precision=0.0001, max_iter=n)

mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                             multiplier=0.001, precision=0.0001, max_iter=n)  # [REQUIRED]

high_gamma = gradient_descent(derivative_func=dg, initial_guess=3,
                              multiplier=0.002, precision=0.0001, max_iter=n)  # [REQUIRED]

# Experiment with an "insane" learning rate
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9,
                                multiplier=0.25, precision=0.0001, max_iter=n)

# %%
# Extract values from gradient descent
low_x_list = low_gamma[1]
mid_x_list = mid_gamma[1]
high_x_list = high_gamma[1]
insane_x_list = insane_gamma[1]

# Data for the function
x = np.linspace(-2, 4, 1000)

# Plot g(x) with paths for different learning rates
plt.figure(figsize=(14, 8))
plt.plot(x, g(x), label='g(x)', color='black', linewidth=2)

# Plot paths for each learning rate
plt.scatter(low_x_list, [g(i) for i in low_x_list], color='blue', label='Low Learning Rate (0.0005)', s=20)
plt.scatter(mid_x_list, [g(i) for i in mid_x_list], color='green', label='Mid Learning Rate (0.001)', s=20)
plt.scatter(high_x_list, [g(i) for i in high_x_list], color='red', label='High Learning Rate (0.002)', s=20)
plt.scatter(insane_x_list, [g(i) for i in insane_x_list], color='purple', label='Insane Learning Rate (0.25)', s=20)

# Add titles and labels
plt.title('Gradient Descent with Different Learning Rates', fontsize=16)
plt.xlabel('x', fontsize=14)
plt.ylabel('g(x)', fontsize=14)
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.grid()
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# ### Example 4 - Data Viz with 3D Charts
#
# #### Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function h(x) and its derivative h'(x)
def h(x):
    return x**3 - 3*x**2 + 2  # Example function

def dh(x):
    return 3*x**2 - 6*x  # Derivative of h(x)

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]
    cost_list = [h(new_x)]  # Track cost (function value)

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))
        cost_list.append(h(new_x))  # Add the cost at each iteration

        if step_size < precision:
            break
    return new_x, x_list, slope_list, cost_list

# Number of iterations
n = 100

# Run gradient descent for different learning rates
low_gamma = gradient_descent(derivative_func=dh, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)
mid_gamma = gradient_descent(derivative_func=dh, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)
high_gamma = gradient_descent(derivative_func=dh, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)
insane_gamma = gradient_descent(derivative_func=dh, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Extract values from gradient descent
low_x_list = low_gamma[1]
mid_x_list = mid_gamma[1]
high_x_list = high_gamma[1]
insane_x_list = insane_gamma[1]

# Data for the function
x = np.linspace(-2, 4, 1000)

# Plot h(x) with paths for different learning rates
plt.figure(figsize=(14, 8))
plt.plot(x, h(x), label='h(x)', color='black', linewidth=2)

# Plot paths for each learning rate
plt.scatter(low_x_list, [h(i) for i in low_x_list], color='blue', label='Low Learning Rate (0.0005)', s=20)
plt.scatter(mid_x_list, [h(i) for i in mid_x_list], color='green', label='Mid Learning Rate (0.001)', s=20)
plt.scatter(high_x_list, [h(i) for i in high_x_list], color='red', label='High Learning Rate (0.002)', s=20)
plt.scatter(insane_x_list, [h(i) for i in insane_x_list], color='purple', label='Insane Learning Rate (0.25)', s=20)

# Add titles and labels
plt.title('Gradient Descent with Different Learning Rates for h(x)', fontsize=16)
plt.xlabel('x', fontsize=14)
plt.ylabel('h(x)', fontsize=14)
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.grid()
plt.legend(fontsize=12)
plt.show()

# Extract cost values for each iteration
low_costs = low_gamma[3]
mid_costs = mid_gamma[3]
high_costs = high_gamma[3]
insane_costs = insane_gamma[3]

# Number of iterations
iterations = range(len(low_costs))  # Assuming all have the same max_iter

# Plot the cost reduction
plt.figure(figsize=(14, 8))

plt.plot(iterations, low_costs, label='Low Learning Rate (0.0005)', color='blue')
plt.plot(iterations, mid_costs, label='Mid Learning Rate (0.001)', color='green')
plt.plot(iterations, high_costs, label='High Learning Rate (0.002)', color='red')
plt.plot(iterations, insane_costs, label='Insane Learning Rate (0.25)', color='purple')

# Titles and labels
plt.title('Reduction in Cost per Iteration for h(x)', fontsize=16)
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('Cost (h(x))', fontsize=14)
plt.legend(fontsize=12)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-f40e57ebdc24> in <cell line: 84>()
#      82 plt.plot(iterations, mid_costs, label='Mid Learning Rate (0.001)', color='green')
#      83 plt.plot(iterations, high_costs, label='High Learning Rate (0.002)', color='red')
# ---> 84 plt.plot(iterations, insane_costs, label='Insane Learning Rate (0.25)', color='purple')
#      85
#      86 # Titles and labels
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1719         """
# ...

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-0c086e9e446f> in <cell line: 3>()
#       1 # Generating 3D Plot
#       2 fig = plt.figure(figsize=[16, 12])
# ----> 3 ax = fig.gca(projection='3d')
#       4
#       5 ax.set_xlabel('X', fontsize=20)
#
# TypeError: FigureBase.gca() got an unexpected keyword argument 'projection'

# %% [markdown]
# ### TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
#
# #### Partial Derivatives & Symbolic Computation
#
# #### $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# #### $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
a, b = symbols('x, y')
print('Our cost function f(x, y) is: ', f(a, b))
print('Partial derivative wrt x is: ', diff(f(a, b), b))
print('Value of f(x,y) at x=1.8 y=1.0 is: ',
      f(a, b).evalf(subs={a:1.8, b:1.0})) # Python Dictionary
print('Value of partial derivative wrt x: ', diff(f(a, b), a).evalf(subs={a:1.8, b:1.0}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-076a7a187497> in <cell line: 2>()
#       1 a, b = symbols('x, y')
# ----> 2 print('Our cost function f(x, y) is: ', f(a, b))
#       3 print('Partial derivative wrt x is: ', diff(f(a, b), b))
#       4 print('Value of f(x,y) at x=1.8 y=1.0 is: ',
#       5       f(a, b).evalf(subs={a:1.8, b:1.0})) # Python Dictionary
#
# TypeError: f() takes 1 positional argument but 2 were given

# %% [markdown]
# #### Batch Gradient Descent with SymPy
#
# *   List item
# *   List item

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [2.01013037525579e-11 1.11673909736433e-11]
# Minimum occurs at x value of:  3.45838599885832e-11
# Minimum occurs at y value of:  1.92132555492129e-11
# The cost is:  0.500000000000000

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
def fpx(x, y):
    return ## [REQUIRED]

def fpy(x, y):
    return ## [REQUIRED]

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))

# %% [markdown]
# ```
# #### This is formatted as code
# ```
#
# ### Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# #### For Reference, practice and play with the code below
#
# ### Example 5 - Working with data & a real cost function
#
# #### Mean Squared Error: a cost function for regression problems
#
# #### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# #### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# #### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.847535148603
# Theta 1: 1.22272646378

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[ 0.96980779]
#  [ 2.31480691]
#  [ 3.78207866]
#  [ 4.76025983]
#  [ 5.86071365]
#  [ 7.81707599]
#  [ 8.79525716]]
# In comparison, the actual y values are
#  [[ 1.7]
#  [ 2.4]
#  [ 3.5]
#  [ 3. ]
#  [ 6.1]
#  [ 9.4]
#  [ 8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [ 0.94796558]
# MSE regression using manual calc is 0.947965575979
# MSE regression is 0.947965575979

# %% [markdown]
# #### 3D Plot for the MSE Cost Function
#
# #### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# #### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(indices=plot_cost.argmin(), dims=plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[111][91])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[111][91])
# Out:
# Min value of plot_cost 0.948382652675
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643
# Min MSE for Theta 1 at plot_t1[111][91] 1.23115577889

# %% [markdown]
# #### Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# #### $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# #### $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# #### MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.853223046174
# Min occurs at Theta 1: 1.22149353326
# MSE is: [ 0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.gca(projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
